# %%
import matplotlib.pyplot as plt

def visualise(df):
    plt.figure(figsize=(10, 6))
    plt.plot(df['day'], df['visits'], label='Total Visits')
    plt.plot(df['day'], df['registrations'], label='Registrations')
    plt.plot(df['day'], df['existing_users'], label='Existing Users')
    plt.xlabel('Day')
    plt.ylabel('Count')
    plt.title('Simulated Visits and User Registrations Over One Year')
    plt.legend()
    plt.show()

# %%
import numpy as np
import pandas as pd

# Parameters
days = 365
base_visits_per_day = 10
user_visiting_prob = 0.1
new_user_prob = 0.2
new_user_ = 0.2
registration_prob = 0.3

# Initialize DataFrame to store results
df = pd.DataFrame(index=range(days), columns=['day', 'visits', 'new_users', 'registrations', 'existing_users'])

existing_users = 1
new_users = 0

for day in range(365):
    # Simulate number of visits
    # print(existing_users)
    
    visits = np.random.poisson(base_visits_per_day + np.random.binomial(existing_users, user_visiting_prob))
    
    
    # # Simulate new user visits
    new_user = np.random.binomial(visits, new_user_prob)
    existing_users += new_user
    
    # # Simulate registrations from new users
    # registrations = np.random.binomial(new_user_visits, registration_prob)
    # new_users += registrations
    
    # # Update existing users pool
    # existing_users += (new_user_visits - registrations)
    
    # Store results
    df.loc[day] = [day, visits, new_user_visits, registrations, existing_users]

# Output the simulation results
df.head(50)
# Out:
#    day visits new_users registrations existing_users
# 0    0     10        17             6              3
# 1    1     13        17             6              4
# 2    2     10        17             6              6
# 3    3     13        17             6             10
# 4    4     10        17             6             10
# 5    5     11        17             6             12
# 6    6      8        17             6             12
# 7    7      7        17             6             13
# 8    8      8        17             6             16
# 9    9      7        17             6             16
# 10  10     16        17             6             22
# 11  11     18        17             6             26
# 12  12     11        17             6             27
# 13  13      7        17             6             29
# 14  14     11        17             6             30
# 15  15     19        17             6             32
# 16  16     14        17             6             34
# ...

# %%
visualise(df)

# %%
import numpy as np

# %%
np.random.randint(10000000)
# Out:
# 9056751

# %%
class UserType:
    NEW_USER = 'new_user'
    RETURNING_USER = 'returning_user'
    REGISTERED_USER = 'registered_user'




user_type_predictions = {
    UserType.NEW_USER: 0.3,
    UserType.RETURNING_USER: 0.1,
    UserType.REGISTERED_USER: 0.6
}

# %%
user_type_predictions.keys()
# Out:
# dict_keys(['new_user', 'returning_user', 'registered_user'])

# %%
user_type_predictions.values()
# Out:
# dict_values([0.3, 0.1, 0.6])

# %%
user_type = np.random.choice(
    list(user_type_predictions.keys()),
    p=list(user_type_predictions.values()))

# %%
print(user_type)
# Out:
# returning_user

# %%
from sqlite3 import connect
conn = connect(':memory:')
df = pd.DataFrame(data=[[0, '10/11/12'], [1, '12/11/10']],
                  columns=['int_column', 'date_column'])
df.to_sql(name='test_data', con=conn)
